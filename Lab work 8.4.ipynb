# %%
                                                        #1. Introduction to Pandas

# %%
#Task 1.1: Importing Pandas
#Import the Pandas library and assign it the conventional alias pd.

import pandas as pd


#Task 1.2: Understanding Pandas Data Structures
#Briefly explain in a comment what the two primary data structures in Pandas are and what they represent.

# Pandas has two primary data structures:

# 1. Series:
#    A one-dimensional labeled array that can store data like integers,
#    strings, or floats. It is similar to a single column in a table.

# 2. DataFrame:
#    A two-dimensional labeled data structure with rows and columns.
#    It is similar to an Excel sheet or SQL table and can store different
#    types of data in different columns.

# %%
                                                               #2. Series

# %%
#Task 2.1: Creating a Series from a List
#Create a Pandas Series named fruits from the following Python list: ['apple', 'banana', 'cherry', 'date'].
#Print the Series.

fruits = pd.Series(['apple','banana','cherry','date'])
print(fruits)

# Task 2.2: Creating a Series with Custom Indices
# Create a Pandas Series named colors from the following Python list: ['red', 'green', 'blue'].
# Assign the indices as ['color1', 'color2', 'color3'].
# Print the Series.

colours = pd.Series(['red','green','blue'],index=['color1','color2','color3'])
print(colours)

# Task 2.3: Accessing Elements in a Series
# Using the fruits Series, access and print the element at index 1.
# Using the colors Series, access and print the element with the index 'color2'.

print('fruits index 1 : ',fruits[1])

print("-----------------------------------")

print("color index 'color2' : ",colours['color2'])
# Out:
# 0     apple
# 1    banana
# 2    cherry
# 3      date
# dtype: object
# color1      red
# color2    green
# color3     blue
# dtype: object
# fruits index 1 :  banana
# -----------------------------------
# color index 'color2' :  green

# %%
                                                              #3. DataFrame

# %%
# Task 3.1: Creating a DataFrame from a Dictionary of Lists
# Create a Pandas DataFrame named student_data from the following Python dictionary:
# {
# 'name': ['Alice', 'Bob', 'Charlie'],
# 'age': [20, 21, 19],
# 'major': ['CS', 'Engineering', 'Math']
# }
# Print the DataFrame.

student_data = pd.DataFrame({"name" : ['Alice','Bob','Charlie'],"age" : [20,21,19],"major" : ['CS','Engineering','Math']})
print(student_data)

print("--------------------------")
# Task 3.2: Creating a DataFrame from a List of Dictionaries
# Create a Pandas DataFrame named employee_data from the following Python list of dictionaries:
# [{'name': 'David', 'salary': 50000, 'department': 'Sales'},
# {'name': 'Eve', 'salary': 60000, 'department': 'Marketing'},
# {'name': 'Frank', 'salary': 55000, 'department': 'Sales'}]
# Print the DataFrame.

employee_data = pd.DataFrame([{'name': 'David', 'salary': 50000, 'department': 'Sales'},
                              {'name': 'Eve', 'salary': 60000, 'department': 'Marketing'},
                              {'name': 'Frank', 'salary': 55000, 'department': 'Sales'}])
print(employee_data)

print("---------------------------")

# Task 3.3: Creating a DataFrame from a NumPy Array
# Create a NumPy array data_array with shape (3, 2) containing random integers between 1 and 10.
# Create a Pandas DataFrame named random_df from this NumPy array with column names 'Column A' and 'Column B'.
# Print the DataFrame.

import numpy as np

data_array = np.random.randint(1,11,size = (3,2))
print(data_array)

print("---------------------------")

random_df = pd.DataFrame(data_array ,columns = ['column A','column B'])
print(random_df)
# Out:
#       name  age        major
# 0    Alice   20           CS
# 1      Bob   21  Engineering
# 2  Charlie   19         Math
# --------------------------
#     name  salary department
# 0  David   50000      Sales
# 1    Eve   60000  Marketing
# 2  Frank   55000      Sales
# ---------------------------
# [[ 5 10]
#  [10  4]
#  [ 2  1]]
# ---------------------------
#    column A  column B
# 0         5        10
# 1        10         4
# 2         2         1

# %%
                                        #4. Exploring Data (Series and DataFrame)

# %%
# Task 4.1: Exploring a Series
# Using the fruits Series, find and print:
# - The number of elements in the Series.
# - The unique values in the Series.
# - The count of each unique value in the Series.

fruits = pd.Series(['apple','banana','strawberries','mango'])

print("fruits:\n",fruits)
print("---------------------------")
print('Size :\n',fruits.size)
print("---------------------------")
print('value :\n',fruits.value_counts())
print("---------------------------")
print('unique :\n',fruits.unique())

print("\n=================================\n")


# Task 4.2: Exploring a DataFrame
# Using the student_data DataFrame, find and print:
# - The first 2 rows of the DataFrame.
# - The last row of the DataFrame.
# - The index of the DataFrame.
# - The column names of the DataFrame.
# - A concise summary of the DataFrame (including data types and non-null values).

student_data = pd.DataFrame({'name':['vishnu','jay','divyesh'],
                              'studentid':[101,102,103],
                              'age' :[22,14,11]})
print(student_data)

d = student_data
print("---------------------------")

print(d.head(2))

print("---------------------------")

print(d.tail(1))

print("---------------------------")

print(d.index)

print("---------------------------")

print(d.columns.tolist())

print("---------------------------")

print(d.info())

# Task 4.3: Selecting Columns and Rows
# Using the employee_data DataFrame:
# - Select and print only the 'name' column.
# - Select and print the row at index 1.
# - Select and print the 'name' and 'salary' columns.
# - Select and print the first two rows and the 'name' and 'department' columns.

data = pd.DataFrame({'name':['vishnu','rahul','nevil'],
                     'salary':[20000,30000,40000],
                     'department':['CS','CA','ACCA']})

f = data

print(f)
print("---------------------------")
print(f.name)
print("---------------------------")
print(f.iloc[1])
print("---------------------------")
print(f[['name','department']])
print("---------------------------")
print(f.loc[0:1,['name','department']])
# Out:
# fruits:
#  0           apple
# 1          banana
# 2    strawberries
# 3           mango
# dtype: object
# ---------------------------
# Size :
#  4
# ---------------------------
# value :
#  apple           1
# banana          1
# strawberries    1
# mango           1
# Name: count, dtype: int64
# ---------------------------
# unique :
#  ['apple' 'banana' 'strawberries' 'mango']
#
# =================================
#
#       name  studentid  age
# 0   vishnu        101   22
# 1      jay        102   14
# 2  divyesh        103   11
# ---------------------------
#      name  studentid  age
# 0  vishnu        101   22
# 1     jay        102   14
# ---------------------------
#       name  studentid  age
# 2  divyesh        103   11
# ---------------------------
# RangeIndex(start=0, stop=3, step=1)
# ---------------------------
# ['name', 'studentid', 'age']
# ---------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       3 non-null      object
#  1   studentid  3 non-null      int64
#  2   age        3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes
# None
#      name  salary department
# 0  vishnu   20000         CS
# 1   rahul   30000         CA
# 2   nevil   40000       ACCA
# ---------------------------
# 0    vishnu
# 1     rahul
# 2     nevil
# Name: name, dtype: object
# ---------------------------
# name          rahul
# salary        30000
# department       CA
# Name: 1, dtype: object
# ---------------------------
#      name department
# 0  vishnu         CS
# 1   rahul         CA
# 2   nevil       ACCA
# ---------------------------
#      name department
# 0  vishnu         CS
# 1   rahul         CA

# %%
                                               # 5. Operations on DataFrames

# %%
# Task 5.1: Adding a New Column
# Add a new column named 'city' to the student_data DataFrame with the values: ['New York', 'London', 'Paris'].
# Print the updated DataFrame.

f['city'] = ['new york','london','paris']

print(f)
print("---------------------------")

# Task 5.2: Removing a Column
# Remove the 'city' column from the student_data DataFrame.
# Print the DataFrame after removal.

f.drop('city',axis = 1)
print(f)
print("---------------------------")


# Task 5.3: Filtering Rows Based on a Condition
# Using the employee_data DataFrame, filter and print the rows where the 'department' is 'Sales'.
j = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank'],
    'department': ['HR', 'IT', 'Finance', 'sales', 'Marketing', 'sales'],
    'salary': [55000, 72000, 68000, 75000, 61000, 80000],
    'experience': [3, 7, 5, 6, 4, 9]})
l = j[j['department']=='sales']
print(l)
print("---------------------------")

# Task 5.4: Sorting a DataFrame
# Sort the employee_data DataFrame by the 'salary' column in descending order.
# Print the sorted DataFrame.

S = j.sort_values(by='salary',ascending=False)
print(S)
print("---------------------------")

# Task 5.5: Basic Aggregation
# Using the employee_data DataFrame, calculate and print the average salary of all employees.


avg_salary = j['salary'].mean()
print(avg_salary)
# Out:
#      name  salary department      city
# 0  vishnu   20000         CS  new york
# 1   rahul   30000         CA    london
# 2   nevil   40000       ACCA     paris
# ---------------------------
#      name  salary department      city
# 0  vishnu   20000         CS  new york
# 1   rahul   30000         CA    london
# 2   nevil   40000       ACCA     paris
# ---------------------------
#     name department  salary  experience
# 3  Diana      sales   75000           6
# 5  Frank      sales   80000           9
# ---------------------------
#       name department  salary  experience
# 5    Frank      sales   80000           9
# 3    Diana      sales   75000           6
# 1      Bob         IT   72000           7
# 2  Charlie    Finance   68000           5
# 4      Eve  Marketing   61000           4
# 0    Alice         HR   55000           3
# ---------------------------
# 68500.0
